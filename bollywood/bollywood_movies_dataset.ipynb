# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/bollywood_movies_dataset.csv')

# %%
df.head()
# Out:
#          Movie Name Release Period  Whether Remake  Whether Franchise  \
# 0       Golden Boys         Normal               0                  0
# 1     Kaccha Limboo        Holiday               0                  0
# 2  Not A Love Story        Holiday               0                  0
# 3        Qaidi Band        Holiday               0                  0
# 4         Chaatwali        Holiday               0                  0
#
#       Genre  New Actor  New Director  New Music Director         Lead Star  \
# 0  suspense          1             0                   0      Jeet Goswami
# 1     drama          1             0                   1  Karan Bhanushali
# 2  thriller          0             0                   0        Mahie Gill
# 3     drama          1             0                   0        Aadar Jain
# 4     adult          1             1                   1        Aadil Khan
#
#           Director   Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          1698 non-null   object
#  1   Release Period      1698 non-null   object
#  2   Whether Remake      0 non-null      float64
#  3   Whether Franchise   0 non-null      float64
#  4   Genre               1698 non-null   object
#  5   New Actor           0 non-null      float64
#  6   New Director        1698 non-null   int64
#  7   New Music Director  0 non-null      float64
#  8   Lead Star           1698 non-null   object
#  9   Director            1698 non-null   object
#  10  Music Director      1698 non-null   object
#  11  Number of Screens   1698 non-null   int64
#  12  Revenue(INR)        1698 non-null   int64
#  13  Budget(INR)         1698 non-null   int64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 185.8+ KB

# %%
df['Genre']
# Out:
# 0       suspense
# 1          drama
# 2       thriller
# 3          drama
# 4          adult
#           ...
# 1693      action
# 1694       drama
# 1695       drama
# 1696       drama
# 1697      comedy
# Name: Genre, Length: 1698, dtype: object

# %%
df.groupby('Whether Remake').count()
df.groupby('Genre').count()
# Out:
#               Movie Name  Release Period  Whether Remake  Whether Franchise  \
# Genre
# action               127             127             127                127
# adult                 78              78              78                 78
# animation              3               3               3                  3
# comedy               284             284             284                284
# documentary            1               1               1                  1
# drama                639             639             639                639
# fantasy               13              13              13                 13
# horror                53              53              53                 53
# love_story           133             133             133                133
# masala                16              16              16                 16
# mythological          14              14              14                 14
# ...

# %%
df['Whether Remake'] = df['Whether Remake'].map({'Yes': 1, 'No': 0})
df['Whether Franchise'] = df['Whether Franchise'].map({'Yes': 1, 'No': 0})
df['New Actor'] = df['New Actor'].map({'Yes': 1, 'No': 0})
df['New Music Director'] = df['New Music Director'].map({'Yes': 1, 'No': 0})
df['New Director'] = df['New Director'].map({'Yes': 1, 'No': 0})

# %%
plt.bar(df['Genre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 plt.bar(df['Genre'])
#
# TypeError: bar() missing 1 required positional argument: 'height'
