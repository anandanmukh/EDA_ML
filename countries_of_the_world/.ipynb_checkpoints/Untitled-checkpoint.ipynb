# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
world_data = pd.read_csv('archive/countries of the world.csv', decimal=',')

# %%
world_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
world_data.head(100)
# Out:
#             Country                               Region  Population  \
# 0      Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1          Albania   EASTERN EUROPE                          3581655
# 2          Algeria   NORTHERN AFRICA                        32930091
# 3   American Samoa   OCEANIA                                   57794
# 4          Andorra   WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 95       Indonesia         ASIA (EX. NEAR EAST)            245452739
# 96            Iran         ASIA (EX. NEAR EAST)             68688433
# 97            Iraq   NEAR EAST                              26783383
# 98         Ireland   WESTERN EUROPE                          4062235
# 99     Isle of Man   WESTERN EUROPE                            75441
#
#     Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
sns.heatmap(world_data.corr())
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_25184\1614572157.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(world_data.corr())
# <AxesSubplot: >

# %%
world_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
world_data[world_data['Literacy (%)'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [Country, Region, Population, Area (sq. mi.), Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita), Literacy (%), Phones (per 1000), Arable (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service]
# Index: []

# %%
new_data = world_data.dropna(axis = 0)

# %%
new_data.shape
# Out:
# (179, 20)

# %%
new_data['Literacy (%)']=new_data['Literacy (%)'].astype(float)
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_25184\3582191450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Literacy (%)']=new_data['Literacy (%)'].astype(float)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             179 non-null    object
#  1   Region                              179 non-null    object
#  2   Population                          179 non-null    int64
#  3   Area (sq. mi.)                      179 non-null    int64
#  4   Pop. Density (per sq. mi.)          179 non-null    float64
#  5   Coastline (coast/area ratio)        179 non-null    float64
#  6   Net migration                       179 non-null    float64
#  7   Infant mortality (per 1000 births)  179 non-null    float64
#  8   GDP ($ per capita)                  179 non-null    float64
#  9   Literacy (%)                        179 non-null    float64
#  10  Phones (per 1000)                   179 non-null    float64
# ...

# %%
world_data.shape
# Out:
# (227, 20)

# %%
sns.relplot(y='Birthrate', x='Literacy (%)',hue='Climate', kind = 'scatter', data = world_data)

# %%
sns.relplot(y='Infant mortality (per 1000 births)', x='Literacy (%)',hue='Climate', kind = 'scatter', data = world_data)

# %%
sns.relplot(y='Birthrate', x='Deathrate',hue='Climate', kind = 'scatter', data = world_data)

# %%
sns.scatterplot(x='Deathrate', y = 'GDP ($ per capita)', hue = 'Climate', data = world_data)
# Out:
# <AxesSubplot: xlabel='Deathrate', ylabel='GDP ($ per capita)'>

# %%
sns.scatterplot(x='Service', y = 'GDP ($ per capita)', data = world_data)
# Out:
# <AxesSubplot: xlabel='Service', ylabel='GDP ($ per capita)'>

# %%
sns.scatterplot(x='GDP ($ per capita)', y = 'Agriculture', hue = 'Climate', data = world_data)
# Out:
# <AxesSubplot: xlabel='GDP ($ per capita)', ylabel='Agriculture'>

# %%
sns.scatterplot(x='GDP ($ per capita)', y = 'Phones (per 1000)', hue = 'Climate', data = world_data)
# Out:
# <AxesSubplot: xlabel='GDP ($ per capita)', ylabel='Phones (per 1000)'>

# %%
sns.scatterplot(x='Infant mortality (per 1000 births)', y = 'Birthrate', hue = 'Climate', data = world_data)
# Out:
# <AxesSubplot: xlabel='Infant mortality (per 1000 births)', ylabel='Birthrate'>
